# %% [markdown]
# ### Visualization

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from sklearn import preprocessing

# %%
iris = pd.read_csv('Iris.csv')
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
iris.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
ax = iris[iris.Species=='Iris-setosa'].plot.scatter(x='SepalLengthCm', y='SepalWidthCm', 
                                                    color='red', label='setosa')
iris[iris.Species=='Iris-versicolor'].plot.scatter(x='SepalLengthCm', y='SepalWidthCm', 
                                                color='green', label='versicolor', ax=ax)
iris[iris.Species=='Iris-virginica'].plot.scatter(x='SepalLengthCm', y='SepalWidthCm', 
                                                color='blue', label='virginica', ax=ax)
ax.set_title("scatter")
# Out:
# Text(0.5, 1.0, 'scatter')

# %%
x=iris.Species

# %%
seplen = df.SepalLengthCm
sepwidth = df.SepalWidthCm
petlen = df.PetalLengthCm
petwidth = df.PetalWidthCm

# %%
plt.bar(x,seplen,label="Sepal Length")
plt.bar(x,petlen,label="Petal Length")
plt.title("Length")
plt.legend()

# %%
sns.factorplot('Species',data=iris,kind='count')
# Out:
# C:\Users\pd277\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\categorical.py:3717: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\pd277\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.bar(x,sepwidth,label="Sepal Width")
plt.bar(x,petwidth,label="Petal Width")
plt.title("Width")
plt.legend()

# %%
cat1 = df[df.Species=="Iris-setosa"]
cat2 = df[df.Species=="Iris-versicolor"]
cat3 = df[df.Species=="Iris-virginica"]

# %%
cat1
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0    1            5.1           3.5            1.4           0.2  Iris-setosa
# 1    2            4.9           3.0            1.4           0.2  Iris-setosa
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# ...

# %%
cat2
# Out:
#      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 50   51            7.0           3.2            4.7           1.4
# 51   52            6.4           3.2            4.5           1.5
# 52   53            6.9           3.1            4.9           1.5
# 53   54            5.5           2.3            4.0           1.3
# 54   55            6.5           2.8            4.6           1.5
# 55   56            5.7           2.8            4.5           1.3
# 56   57            6.3           3.3            4.7           1.6
# 57   58            4.9           2.4            3.3           1.0
# 58   59            6.6           2.9            4.6           1.3
# 59   60            5.2           2.7            3.9           1.4
# 60   61            5.0           2.0            3.5           1.0
# 61   62            5.9           3.0            4.2           1.5
# 62   63            6.0           2.2            4.0           1.0
# ...

# %%
cat3
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 100  101            6.3           3.3            6.0           2.5
# 101  102            5.8           2.7            5.1           1.9
# 102  103            7.1           3.0            5.9           2.1
# 103  104            6.3           2.9            5.6           1.8
# 104  105            6.5           3.0            5.8           2.2
# 105  106            7.6           3.0            6.6           2.1
# 106  107            4.9           2.5            4.5           1.7
# 107  108            7.3           2.9            6.3           1.8
# 108  109            6.7           2.5            5.8           1.8
# 109  110            7.2           3.6            6.1           2.5
# 110  111            6.5           3.2            5.1           2.0
# 111  112            6.4           2.7            5.3           1.9
# 112  113            6.8           3.0            5.5           2.1
# ...

# %%
a = cat1["Species"].count()
b = cat2["Species"].count()
c = cat3["Species"].count()
print(a,b,c)
# Out:
# 50 50 50

# %%
values=[a,b,c]
species_labels=["Iris-setosa","Iris-versicolor","Iris-virginica"]
plt.pie(values,labels=species_labels,radius=2,autopct='%0.0f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x192d452faf0>,
# ...
#  [Text(1.099999940539023, 1.905255922655575, 'Iris-setosa'),
#   Text(-2.199999999999991, -2.0597886516130004e-07, 'Iris-versicolor'),
#   Text(1.1000002973048704, -1.9052557166766872, 'Iris-virginica')],
#  [Text(0.5999999675667398, 1.039230503266677, '33%'),
#   Text(-1.1999999999999948, -1.1235210826980001e-07, '33%'),
#   Text(0.6000001621662929, -1.0392303909145566, '33%')])

# %%
plt.boxplot(df["SepalLengthCm"])
plt.boxplot(df["SepalWidthCm"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192d6696110>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192d66966b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192d6695e40>],
#  'medians': [<matplotlib.lines.Line2D at 0x192d6696c50>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192d6696f20>],
#  'means': []}

# %%
plt.boxplot(df["SepalWeidthCm"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x192d66ebf40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x192d6718520>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x192d66ebd90>],
#  'medians': [<matplotlib.lines.Line2D at 0x192d6718ac0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x192d6718d90>],
#  'means': []}

# %%
sns.lmplot(x='SepalLengthCm',y='SepalWidthCm',data=iris)
sns.lmplot(x='PetalLengthCm',y='PetalWidthCm',data=iris)

# %%
sns.residplot(x = iris['SepalLengthCm'], y =iris['SepalWidthCm'], color='red')
sns.residplot(x = iris['PetalLengthCm'], y =iris['PetalWidthCm'], color='red')
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.boxplot(x='Species', y = 'SepalLengthCm', data=iris)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='SepalLengthCm'>
